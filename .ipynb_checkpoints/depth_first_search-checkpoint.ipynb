# %% [markdown]
# # DFS

# %%
# %run Piyush_Lohokare_AI_CW1_230238819.ipynb

# %%
'''
I HAVE TAKEN PARTS OF THIS CODE FROM THE LAB 2 SOLUTION FROM THE FUNCTION "def my_depth_first_graph_search" AND ADDED A FEW OF MY 
OWN LINES OF CODE LIKE THE WAY IN WHICH I AM CALCULATING THE NEIGHBORS.
'''

def depth_first_search(initial, goal, calc_exploration_cost, reverse = False):
    '''
    LIFO_list is a list of dictionaries wherein we are storing the station name, the current station's parent
    stations and the cost to reach this station from the parent
    '''
    LIFO_list = [{'label':initial, 'parent':None, 'cost':0}] # We'll append nodes to the end of this list as it is LIFO
    # List of all the explored nodes. Not necessary that all the nodes in the explored_nodes will be in the solution path
    explored_nodes = [initial]
    num_explored_nodes = 0
    # A list to store all the neighbors of the selected node
    neighbors = []

    # Run the loop until LIFO_list is False, i.e., empty
    while LIFO_list:
        # Get the first element from the LIFO_list in the curr_station variable
        curr_station = LIFO_list.pop() # LIFO so pop the last node from the list as it was added to the list last
        num_explored_nodes += 1

        # print the node that has just been explored
        # print('Exploration '+str(num_explored_nodes)+': ' + curr_station['label'])

        '''
        Check if the station in the just popped node is the goal station.
        If it is, return the current station as the solution
        '''
        if curr_station['label'] == goal:
            if calc_exploration_cost:
                print('\nNumber of explorations = {}'.format(num_explored_nodes))
            return curr_station

        '''
        Generate neighbors:
        station_dict is the dictionary. We are fetching the the values from the dictionary where the
        key is "curr_station['label']"
        curr_station['label'] is the station name that we just popped from the LIFO_list
        So, if the curr_station['label'] is Euston, we'll get all the neighbors of Euston from the station_dict
        '''
        for ind, stn in enumerate(station_dict[curr_station['label']]):
            neighbors.append(stn)

        '''
        If the 'reverse' parameter is passed as True, we'll reverse the list of the neighbors to calculate the path accordingly.
        '''
        if reverse:
            neighbors.reverse()

        '''
        Iterate through the neighbors.
        Get the first neighbor and store its station in the 'label' key, its parent in the 'parent'
        key and cost in the 'cost' key
        '''
        for child_label in neighbors:
            child = {'label':child_label[0], 'parent': curr_station, 'cost':child_label[1]}
            '''
            Check if the station is in the explored_nodes list.
            If not, append the child to the LIFO_list and append the station to the explored_nodes list
            '''
            if child_label[0] not in explored_nodes:
                LIFO_list.append(child)
                explored_nodes.append(child_label[0])

    return None

# %%
# DFS
print('\n=======================================================================================================\n')
print('================================== Depth First Search Implementation ==================================\n')
for stn in test_paths:
    print('Start Station: ', stn[0])
    print('End Station: ', stn[1])
    solution = depth_first_search(stn[0], stn[1], True, reverse=False)
    root_path, cost = construct_path_from_root(solution, stn[0])

    print('\nPath taken:', root_path, '\n\nCost of travel:', cost)
    print('=================================')

print('\n=========================================================================================================================\n')
print('================================== Depth First Search Implementation with reversed Nodes ==================================\n')
for stn in test_paths:
    print('Start Station: ', stn[0])
    print('End Station: ', stn[1])
    solution = depth_first_search(stn[0], stn[1], True, reverse=True)
    root_path, cost = construct_path_from_root(solution, stn[0])

    print('\nPath taken:', root_path, '\n\nCost of travel:', cost)
    print('=================================')
# Out:
# =======================================================================================================
#
# ================================== Depth First Search Implementation ==================================
#
# Start Station:  Euston
# End Station:  Victoria
#
# Number of explorations = 25
#
# Path taken: ['Euston', "King's Cross St. Pancras", 'Russell Square', 'Holborn', 'Covent Garden', 'Leicester Square', 'Piccadilly Circus', 'Green Park', 'Victoria']
#
# Cost of travel: 13
# =================================
# Start Station:  Canada Water
# End Station:  Stratford
#
# Number of explorations = 6
#
# Path taken: ['Canada Water', 'Canary Wharf', 'North Greenwich', 'Canning Town', 'West Ham', 'Stratford']
#
# Cost of travel: 15
# =================================
# Start Station:  New Cross Gate
# End Station:  Stepney Green
#
# Number of explorations = 32
#
# Path taken: ['New Cross Gate', 'Surrey Quays', 'Canada Water', 'Canary Wharf', 'North Greenwich', 'Canning Town', 'West Ham', 'Stratford', 'Mile End', 'Stepney Green']
#
# Cost of travel: 27
# =================================
# Start Station:  Ealing Broadway
# End Station:  South Kensington
#
# Number of explorations = 179
#
# Path taken: ['Ealing Broadway', 'Ealing Common', 'North Ealing', 'Park Royal', 'Alperton', 'Sudbury Town', 'Sudbury Hill', 'South Harrow', 'Rayners Lane', 'West Harrow', 'Harrow-on-the-Hill', 'Northwick Park', 'Preston Road', 'Wembley Park', 'Finchley Road', 'Baker Street', 'Bond Street', 'Green Park', 'Victoria', 'Sloane Square', 'South Kensington']
#
# Cost of travel: 57
# =================================
# Start Station:  Baker Street
# End Station:  Wembley Park
#
# Number of explorations = 3
#
# Path taken: ['Baker Street', 'Finchley Road', 'Wembley Park']
#
# Cost of travel: 13
# =================================
#
# =========================================================================================================================
#
# ================================== Depth First Search Implementation with reversed Nodes ==================================
#
# Start Station:  Euston
# End Station:  Victoria
#
# Number of explorations = 86
#
# Path taken: ['Euston', "King's Cross St. Pancras", 'Farringdon', 'Barbican', 'Moorgate', 'Liverpool Street', 'Bethnal Green', 'Mile End', 'Stratford', 'West Ham', 'Canning Town', 'North Greenwich', 'Canary Wharf', 'Canada Water', 'Bermondsey', 'London Bridge', 'Southwark', 'Waterloo', 'Westminster', "St. James' Park", 'Victoria']
#
# Cost of travel: 49
# =================================
# Start Station:  Canada Water
# End Station:  Stratford
#
# Number of explorations = 228
#
# Path taken: ['Canada Water', 'Rotherhithe', 'Wapping', 'Shadwell', 'Whitechapel', 'Aldgate East', 'Liverpool Street', 'Bethnal Green', 'Mile End', 'Stratford']
#
# Cost of travel: 20
# =================================
# Start Station:  New Cross Gate
# End Station:  Stepney Green
#
# Number of explorations = 268
#
# Path taken: ['New Cross Gate', 'Surrey Quays', 'Canada Water', 'Rotherhithe', 'Wapping', 'Shadwell', 'Whitechapel', 'Stepney Green']
#
# Cost of travel: 14
# =================================
# Start Station:  Ealing Broadway
# End Station:  South Kensington
#
# Number of explorations = 29
#
# Path taken: ['Ealing Broadway', 'West Acton', 'North Acton', 'East Acton', 'White City', "Shepherd's Bush", 'Holland Park', 'Notting Hill Gate', 'Queensway', 'Lancaster Gate', 'Marble Arch', 'Bond Street', 'Oxford Circus', 'Piccadilly Circus', 'Charing Cross', 'Embankment', 'Westminster', "St. James' Park", 'Victoria', 'Sloane Square', 'South Kensington']
#
# Cost of travel: 40
# =================================
# Start Station:  Baker Street
# End Station:  Wembley Park
#
# Number of explorations = 66
#
# Path taken: ['Baker Street', "Regent's Park", 'Oxford Circus', 'Piccadilly Circus', 'Charing Cross', 'Embankment', 'Westminster', "St. James' Park", 'Victoria', 'Sloane Square', 'South Kensington', 'Gloucester Road', 'High Street Kensington', 'Notting Hill Gate', 'Holland Park', "Shepherd's Bush", 'White City', 'East Acton', 'North Acton', 'West Acton', 'Ealing Broadway', 'Ealing Common', 'North Ealing', 'Park Royal', 'Alperton', 'Sudbury Town', 'Sudbury Hill', 'South Harrow', 'Rayners Lane', 'West Harrow', 'Harrow-on-the-Hill', 'Northwick Park', 'Preston Road', 'Wembley Park']
#
# Cost of travel: 78
# =================================
